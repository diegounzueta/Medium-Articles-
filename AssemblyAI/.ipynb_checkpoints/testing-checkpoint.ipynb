# %%
import pandas as pd
import json

# %%
vid1 = "o4kt38ammz-35df-4fde-8e49-44c1d2a2de46.json"

# %%
with open(vid1, "r") as f:
    a = json.load(f)

# %%
highlights_dict = a["auto_highlights_result"]
stafety_labels = a["content_safety_labels"]
categories = a["iab_categories_result"]
chapters_dict = a["chapters"]
sensitive_analysis = a["sentiment_analysis_results"]
entity_detection = a["entities"]
transcript = a["text"]

# %%
pd.DataFrame(chapters_dict)
# Out:
#                                              summary  \
# 0  The best strategic position is to ask yourself...
# 1  People keep saying that you should aim low eno...
# 2  When he was a kid he weighed about £130 and he...
#
#                                             headline  \
# 0  The best strategic position is to ask yourself...
# 1  People keep saying that you should aim low eno...
# 2  When he was a kid, he weighed about £130 and h...
#
#                             gist  start     end
# 0  Your best strategic position.    250   29358
# 1                Aim low enough.  29504   87162
# 2        When you go to the gym.  87236  247570

# %%
stafety_labels
# Out:
# {'status': 'success',
#  'results': [{'text': "Well, what do you do when you go and lift weights? Like, if you have bench press before, you don't put £400 on the damn bar and drop the bar through your skull? You think, look, when I started working out when I was a kid, I was weighed about £130 and I was six foot one. I was a thin kid and I smoked a lot. I wasn't in good shape. I wasn't in good physical shape.",
#    'labels': [{'label': 'tobacco',
#      'confidence': 0.9973272085189819,
#      'severity': 0.022628534585237503}],
#    'timestamp': {'start': 87236, 'end': 107302}},
#   {'text': "No, I had to go in there and strip down and put my skinny goddamn self in front of the mirror and think, Son of a bitch, there's all these monsters in the gym who've been lifting weights for ten years and I'm struggling to get £50 off the bar. Tough luck for me, but I could lift £50 and it wasn't very long until I could lift 75 and, well, you know how it goes.",
#    'labels': [{'label': 'profanity',
#      'confidence': 0.9998304843902588,
#      'severity': 0.02738172747194767},
#     {'label': 'nsfw', 'confidence': 0.9999847412109375, 'severity': None}],
#    'timestamp': {'start': 124388, 'end': 143360}}],
#  'summary': {},
#  'severity_score_summary': {}}

# %%
categories
# Out:
# {'status': 'success',
#  'results': [{'text': "And you might say, well, of course, you know that underestimates the degree to which there's systemic oppression, et cetera, et cetera, and the vagaries of fate, it's like, it doesn't underestimate it. It's not the point. The point is, your best strategic position is, how am I insufficient and how can I rectify that? That's what you've got. And the thing is, you are insufficient and you could rectify it.",
#    'labels': [{'relevance': 0.14876289665699005,
#      'label': 'EventsAndAttractions>PoliticalEvent'},
#     {'relevance': 0.03881504014134407,
#      'label': 'NewsAndPolitics>Politics>PoliticalIssues'},
#     {'relevance': 0.027808304876089096, 'label': 'NewsAndPolitics>Crime'},
#     {'relevance': 0.011180571280419827,
#      'label': 'BusinessAndFinance>Economy>JobMarket'},
#     {'relevance': 0.010577024891972542, 'label': 'NewsAndPolitics>Politics'},
#     {'relevance': 0.00886528566479683,
#      'label': 'MedicalHealth>DiseasesAndConditions>ReproductiveHealth'},
#     {'relevance': 0.008580202236771584,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.006358215119689703,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.005968074779957533,
#      'label': 'NewsAndPolitics>Politics>WarAndConflicts'},
#     {'relevance': 0.004515141248703003,
#      'label': "HealthyLiving>Women'sHealth"}],
#    'timestamp': {'start': 250, 'end': 26262}},
#   {'text': "Both of those are within your grasp if you aim low enough. One of the things that's another thing you keep saying, aim low enough, have a low enough bar. What do you mean that? Well, let's say you've got a kid and you want the kid to improve. You don't set them a bar that's so high that it's impossible for them to attain it.",
#    'labels': [{'relevance': 0.3470045328140259,
#      'label': 'Education>EducationalAssessment'},
#     {'relevance': 0.11665667593479156, 'label': 'Education>HomeworkAndStudy'},
#     {'relevance': 0.041296400129795074,
#      'label': 'Education>EducationalAssessment>StandardizedTesting'},
#     {'relevance': 0.024216679856181145,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.004969457630068064, 'label': 'Education>SpecialEducation'},
#     {'relevance': 0.003751136362552643,
#      'label': 'FamilyAndRelationships>Parenting>ParentingBabiesAndToddlers'},
#     {'relevance': 0.0030844868160784245,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'},
#     {'relevance': 0.002513824962079525, 'label': 'Education>AdultEducation'},
#     {'relevance': 0.0012375011574476957,
#      'label': 'FamilyAndRelationships>Parenting>SpecialNeedsKids'},
#     {'relevance': 0.0011003526160493493,
#      'label': 'Education>LanguageLearning'}],
#    'timestamp': {'start': 26396, 'end': 41802}},
#   {'text': "You take a look at the kid and you think, okay, this kid's got this range of skill here's a challenge we can throw at him or her that exceeds their current level of skill but gives them a reasonable probability of success. And so, like I'm saying, it tongue in cheek to some degree, but I'm doing it as an aid to humility it's like, Well, I don't know how to start improving my life. Someone might say that.",
#    'labels': [{'relevance': 0.1776815503835678,
#      'label': 'Education>HomeworkAndStudy'},
#     {'relevance': 0.16552656888961792, 'label': 'Education>AdultEducation'},
#     {'relevance': 0.1064719632267952,
#      'label': 'Education>EarlyChildhoodEducation'},
#     {'relevance': 0.09850934892892838,
#      'label': 'VideoGaming>VideoGameGenres>EducationalVideoGames'},
#     {'relevance': 0.06270521879196167, 'label': 'Careers>CareerPlanning'},
#     {'relevance': 0.046773768961429596,
#      'label': 'Education>EducationalAssessment'},
#     {'relevance': 0.03532117232680321,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'},
#     {'relevance': 0.029367180541157722, 'label': 'Education>SpecialEducation'},
#     {'relevance': 0.012513741850852966, 'label': 'Careers'},
#     {'relevance': 0.009278352372348309, 'label': 'Education'}],
#    'timestamp': {'start': 41936, 'end': 64182}},
#   {'text': "And I would say, well, you're not aiming low enough. There's something you could do that you are regarding as trivial that you could do, that you would do that would result in an actual improvement, but it's not a big enough improvement for you, so you won't lower yourself enough to take the opportunity incremental steps. Yeah. So this is also what is achieved through exercise. It's one of the most important. Yeah.",
#    'labels': [{'relevance': 0.9964653253555298,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.08843819051980972, 'label': 'HealthyLiving'},
#     {'relevance': 0.026644282042980194, 'label': 'HealthyLiving>Wellness'},
#     {'relevance': 0.009230665862560272,
#      'label': 'HealthyLiving>Wellness>PhysicalTherapy'},
#     {'relevance': 0.0028477704618126154,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.0025637273211032152, 'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.0025154156610369682, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.0020769303664565086,
#      'label': 'VideoGaming>VideoGameGenres>ExerciseAndFitnessVideoGames'},
#     {'relevance': 0.001989559968933463, 'label': 'Sports>Cycling'},
#     {'relevance': 0.0014129416085779667,
#      'label': 'Education>HomeworkAndStudy'}],
#    'timestamp': {'start': 64256, 'end': 82938}},
#   {'text': "Well, what do you do when you go and lift weights? Like, if you have bench press before, you don't put £400 on the damn bar and drop the bar through your skull? You think, look, when I started working out when I was a kid, I was weighed about £130 and I was six foot one. I was a thin kid and I smoked a lot. I wasn't in good shape. I wasn't in good physical shape.",
#    'labels': [{'relevance': 0.877774178981781, 'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.7518988251686096, 'label': 'Sports>Weightlifting'},
#     {'relevance': 0.21141304075717926,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.0021792775951325893, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.0003514898708090186,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.000259645952610299,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.00019551339210011065,
#      'label': 'Food&Drink>HealthyCookingAndEating'},
#     {'relevance': 0.00018102685862686485, 'label': 'HealthyLiving>Nutrition'},
#     {'relevance': 0.0001762853207765147, 'label': 'HealthyLiving'},
#     {'relevance': 0.00017413889872841537,
#      'label': 'Education>HomeworkAndStudy'}],
#    'timestamp': {'start': 87236, 'end': 107302}},
#   {'text': "And I went to the gym and it was bloody embarrassing. And people would come over and help me with the goddamn weights. Here's how you're supposed to use this. It was humiliating and maybe I was pressing £65 or something at that point, but what am I going to do? I'm going to lift up £150 and injure myself right off the bat.",
#    'labels': [{'relevance': 0.9824684262275696,
#      'label': 'Sports>Weightlifting'},
#     {'relevance': 0.8858015537261963, 'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.20695467293262482,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.0010315654799342155,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.0009626008686609566, 'label': 'Sports>Gymnastics'},
#     {'relevance': 0.00034190091537311673,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.0002782332885544747,
#      'label': 'Education>HomeworkAndStudy'},
#     {'relevance': 0.00022429978707805276, 'label': 'Sports>Boxing'},
#     {'relevance': 0.00021557377476710826,
#      'label': 'Education>EducationalAssessment'},
#     {'relevance': 0.00019723072182387114,
#      'label': 'HealthyLiving>Wellness>PhysicalTherapy'}],
#    'timestamp': {'start': 107386, 'end': 124266}},
#   {'text': "No, I had to go in there and strip down and put my skinny goddamn self in front of the mirror and think, Son of a bitch, there's all these monsters in the gym who've been lifting weights for ten years and I'm struggling to get £50 off the bar. Tough luck for me, but I could lift £50 and it wasn't very long until I could lift 75 and, well, you know how it goes.",
#    'labels': [{'relevance': 0.9533775448799133,
#      'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.8755741715431213, 'label': 'Sports>Weightlifting'},
#     {'relevance': 0.06140090897679329,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.0004619912360794842, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.00020120378758292645, 'label': 'Sports>Gymnastics'},
#     {'relevance': 0.00016593131294939667,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.00015926822379697114,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.00014121569984126836, 'label': 'Sports>Boxing'},
#     {'relevance': 0.00013601973478216678,
#      'label': "Style&Fashion>Men'sFashion>Men'sClothing>Men'sSportswear"},
#     {'relevance': 0.00012108149530831724, 'label': 'HealthyLiving>Wellness'}],
#    'timestamp': {'start': 124388, 'end': 143360}},
#   {'text': "And I never injured myself when I was weight lifting and the reason for that was I never pushed myself past where I knew I could go and I pushed myself a lot I gained £35 of muscle in about three years in University I kind of had to quit because I was eating so goddamn much I couldn't stand it. I was eating like six meals a day.",
#    'labels': [{'relevance': 0.9891502261161804,
#      'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.4398195147514343, 'label': 'Sports>Weightlifting'},
#     {'relevance': 0.06186772510409355,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.0022500245831906796, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.00039271562127396464, 'label': 'HealthyLiving>Wellness'},
#     {'relevance': 0.0003677316999528557,
#      'label': "Style&Fashion>Men'sFashion>Men'sClothing>Men'sSportswear"},
#     {'relevance': 0.0003492322866804898,
#      'label': 'HealthyLiving>FitnessAndExercise>ParticipantSports'},
#     {'relevance': 0.0002828340802807361, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0002696156152524054,
#      'label': "Style&Fashion>Women'sFashion>Women'sClothing>Women'sSportswear"},
#     {'relevance': 0.00019358881399966776,
#      'label': 'BusinessAndFinance>Business>HumanResources'}],
#    'timestamp': {'start': 143750, 'end': 161814}},
#   {'text': "It was just taking up too much time but there's a humility in determining what it is that the wretched creature that you are can actually manage aim low and I don't mean don't aim And I don't mean don't aim up but you have to accept the fact that you can set yourself a goal that you can attain and there's not going to be much glory in it to begin with because if you're not in very good shape the goal that you could attain tomorrow isn't very glorious but it's a hell of a lot better than nothing and it beats the hell out of bitterness and it's way better than blaming someone else.",
#    'labels': [{'relevance': 0.44074615836143494,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.3213679790496826, 'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.019811144098639488, 'label': 'HealthyLiving>Wellness'},
#     {'relevance': 0.014477111399173737, 'label': 'HealthyLiving'},
#     {'relevance': 0.0060984352603554726, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.0024342508986592293,
#      'label': 'BusinessAndFinance>Business>HumanResources'},
#     {'relevance': 0.001232996117323637, 'label': 'Sports>Weightlifting'},
#     {'relevance': 0.0008219871670007706,
#      'label': 'BusinessAndFinance>Business>ExecutiveLeadership&Management'},
#     {'relevance': 0.0006650412688031793, 'label': "HealthyLiving>Men'sHealth"},
#     {'relevance': 0.0005683079943992198,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'}],
#    'timestamp': {'start': 161852, 'end': 194598}},
#   {'text': "It's way less dangerous and you could do it and what's cool about it there's a statement in the new testament it's called the Matthew principle and economists use it to describe how the economy and the world works to those who have everything more will be given from those who have nothing everything will be taken.",
#    'labels': [{'relevance': 0.03338829427957535,
#      'label': 'BusinessAndFinance>Economy>Commodities'},
#     {'relevance': 0.017335863783955574, 'label': 'BusinessAndFinance>Economy'},
#     {'relevance': 0.008536562323570251,
#      'label': 'PersonalFinance>FrugalLiving'},
#     {'relevance': 0.005007484927773476,
#      'label': 'Religion&Spirituality>Judaism'},
#     {'relevance': 0.0012092596152797341,
#      'label': 'PersonalFinance>FinancialAssistance>GovernmentSupportAndWelfare'},
#     {'relevance': 0.0007359651499427855, 'label': 'PersonalFinance'},
#     {'relevance': 0.0005194182158447802,
#      'label': 'PersonalFinance>PersonalDebt'},
#     {'relevance': 0.0004993201000615954,
#      'label': 'PersonalFinance>PersonalInvesting'},
#     {'relevance': 0.0004804464988410473,
#      'label': 'BusinessAndFinance>Economy>GasolinePrices'},
#     {'relevance': 0.00038729255902580917,
#      'label': 'NewsAndPolitics>Politics'}],
#    'timestamp': {'start': 194684, 'end': 211206}},
#   {'text': "It's like what's very pessimistic in some sense because it means that as you start to fail you fail more and more rapidly but it also means that as you start to succeed you succeed more and more rapidly and so you take an incremental step and, well, now you can lift £55 instead of £52.5. You think, well, what the hell is that?",
#    'labels': [{'relevance': 0.15179571509361267,
#      'label': 'Sports>Weightlifting'},
#     {'relevance': 0.047103725373744965,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.016706613823771477, 'label': 'Sports>Bodybuilding'},
#     {'relevance': 0.00224046828225255,
#      'label': 'Sports>ExtremeSports>Climbing'},
#     {'relevance': 0.0005518784164451063, 'label': 'HealthyLiving>WeightLoss'},
#     {'relevance': 0.0005153310485184193, 'label': 'HealthyLiving'},
#     {'relevance': 0.0003088484809268266,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.00029608976910822093, 'label': 'Sports>Gymnastics'},
#     {'relevance': 0.0001669729535933584,
#      'label': 'MedicalHealth>DiseasesAndConditions>MentalHealth'},
#     {'relevance': 0.00016528042033314705, 'label': 'Sports>ExtremeSports'}],
#    'timestamp': {'start': 211328, 'end': 230490}},
#   {'text': "It's one step on a very long journey and it starts to compound on you so a small step today means puts you in a position to take a slight bigger step the next day and then that puts you in a position to take a slightly bigger step the next day and you do that for two or three years, man. You're starting to stride.",
#    'labels': [{'relevance': 0.08424977958202362,
#      'label': 'FamilyAndRelationships>Parenting>ParentingBabiesAndToddlers'},
#     {'relevance': 0.026172665879130363,
#      'label': 'HealthyLiving>FitnessAndExercise>RunningAndJogging'},
#     {'relevance': 0.003046560101211071, 'label': 'Sports>DisabledSports'},
#     {'relevance': 0.00249421875923872,
#      'label': 'HealthyLiving>FitnessAndExercise'},
#     {'relevance': 0.0012599354377016425,
#      'label': 'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11'},
#     {'relevance': 0.0009998398600146174,
#      'label': 'Education>LanguageLearning'},
#     {'relevance': 0.00095205387333408, 'label': 'Sports>Walking'},
#     {'relevance': 0.0007434495491907,
#      'label': 'MedicalHealth>DiseasesAndConditions>Injuries'},
#     {'relevance': 0.0006186618120409548, 'label': 'Education>AdultEducation'},
#     {'relevance': 0.0005412001046352088,
#      'label': 'MedicalHealth>DiseasesAndConditions>FootHealth'}],
#    'timestamp': {'start': 230660, 'end': 247570}}],
#  'summary': {'Sports>Bodybuilding': 1.0,
#   'Sports>Weightlifting': 0.7915369868278503,
#   'HealthyLiving>FitnessAndExercise': 0.5026712417602539,
#   'Education>EducationalAssessment': 0.09799038618803024,
#   'Education>HomeworkAndStudy': 0.07338698208332062,
#   'Education>AdultEducation': 0.04209749028086662,
#   'EventsAndAttractions>PoliticalEvent': 0.03690379112958908,
#   'Education>EarlyChildhoodEducation': 0.0323912650346756,
#   'HealthyLiving': 0.026284800842404366,
#   'VideoGaming>VideoGameGenres>EducationalVideoGames': 0.02470487914979458,
#   'FamilyAndRelationships>Parenting>ParentingBabiesAndToddlers': 0.023900266736745834,
#   'Careers>CareerPlanning': 0.015701713040471077,
#   'HealthyLiving>Wellness': 0.011889729648828506,
#   'Education>EducationalAssessment>StandardizedTesting': 0.01097115594893694,
#   'NewsAndPolitics>Politics>PoliticalIssues': 0.009953172877430916,
#   'FamilyAndRelationships>Parenting>ParentingChildrenAged4-11': 0.009851060807704926,
#   'Education>SpecialEducation': 0.008826064877212048,
#   'BusinessAndFinance>Economy>Commodities': 0.008356571197509766,
#   'HealthyLiving>FitnessAndExercise>RunningAndJogging': 0.007849243469536304,
#   'NewsAndPolitics>Crime': 0.006958650425076485}}

# %%
sensitive_analysis
# Out:
# [{'text': "And you might say, well, of course, you know that underestimates the degree to which there's systemic oppression, et cetera, et cetera, and the vagaries of fate, it's like, it doesn't underestimate it.",
#   'start': 250,
#   'end': 11982,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.5206404328346252,
#   'speaker': None},
#  {'text': "It's not the point.",
#   'start': 11996,
#   'end': 13110,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.5358428955078125,
#   'speaker': None},
#  {'text': 'The point is, your best strategic position is, how am I insufficient and how can I rectify that?',
#   'start': 13280,
#   'end': 20418,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.6631900072097778,
#   'speaker': None},
#  {'text': "That's what you've got.",
#   'start': 20564,
#   'end': 21606,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.5626523494720459,
#   'speaker': None},
#  {'text': 'And the thing is, you are insufficient and you could rectify it.',
#   'start': 21668,
#   'end': 26262,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.6706990599632263,
#   'speaker': None},
#  {'text': 'Both of those are within your grasp if you aim low enough.',
#   'start': 26396,
#   'end': 29358,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.7051694393157959,
#   'speaker': None},
#  {'text': "One of the things that's another thing you keep saying, aim low enough, have a low enough bar.",
#   'start': 29504,
#   'end': 34422,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.5178938508033752,
#   'speaker': None},
#  {'text': 'What do you mean that?',
#   'start': 34556,
#   'end': 35442,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.7504233121871948,
#   'speaker': None},
#  {'text': "Well, let's say you've got a kid and you want the kid to improve.",
#   'start': 35516,
#   'end': 38026,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.7145246863365173,
#   'speaker': None},
#  {'text': "You don't set them a bar that's so high that it's impossible for them to attain it.",
#   'start': 38098,
#   'end': 41802,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.5806463360786438,
#   'speaker': None},
#  {'text': "You take a look at the kid and you think, okay, this kid's got this range of skill here's a challenge we can throw at him or her that exceeds their current level of skill but gives them a reasonable probability of success.",
#   'start': 41936,
#   'end': 53540,
#   'sentiment': 'POSITIVE',
#   'confidence': 0.5609966516494751,
#   'speaker': None},
#  {'text': "And so, like I'm saying, it tongue in cheek to some degree, but I'm doing it as an aid to humility it's like, Well, I don't know how to start improving my life.",
#   'start': 53870,
#   'end': 63006,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.5080882906913757,
#   'speaker': None},
#  {'text': 'Someone might say that.',
#   'start': 63128,
#   'end': 64182,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.6953906416893005,
#   'speaker': None},
#  {'text': "And I would say, well, you're not aiming low enough.",
#   'start': 64256,
#   'end': 66740,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.7389716506004333,
#   'speaker': None},
#  {'text': "There's something you could do that you are regarding as trivial that you could do, that you would do that would result in an actual improvement, but it's not a big enough improvement for you, so you won't lower yourself enough to take the opportunity incremental steps.",
#   'start': 67550,
#   'end': 82510,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.5263332724571228,
#   'speaker': None},
#  {'text': 'Yeah.',
#   'start': 82570,
#   'end': 82938,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.549144983291626,
#   'speaker': None},
#  {'text': 'So this is also what is achieved through exercise.',
#   'start': 83024,
#   'end': 85738,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.6819296479225159,
#   'speaker': None},
#  {'text': "It's one of the most important.",
#   'start': 85774,
#   'end': 86718,
#   'sentiment': 'POSITIVE',
#   'confidence': 0.9250025749206543,
#   'speaker': None},
#  {'text': 'Yeah.',
#   'start': 86804,
#   'end': 87162,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.549144983291626,
#   'speaker': None},
#  {'text': 'Well, what do you do when you go and lift weights?',
#   'start': 87236,
#   'end': 89370,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.8652143478393555,
#   'speaker': None},
#  {'text': "Like, if you have bench press before, you don't put £400 on the damn bar and drop the bar through your skull?",
#   'start': 89690,
#   'end': 95790,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.8879522085189819,
#   'speaker': None},
#  {'text': 'You think, look, when I started working out when I was a kid, I was weighed about £130 and I was six foot one.',
#   'start': 96170,
#   'end': 101594,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.8037782311439514,
#   'speaker': None},
#  {'text': 'I was a thin kid and I smoked a lot.',
#   'start': 101609,
#   'end': 104298,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.502300500869751,
#   'speaker': None},
#  {'text': "I wasn't in good shape.",
#   'start': 104324,
#   'end': 105550,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.8838633894920349,
#   'speaker': None},
#  {'text': "I wasn't in good physical shape.",
#   'start': 105670,
#   'end': 107302,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.8838048577308655,
#   'speaker': None},
#  {'text': 'And I went to the gym and it was bloody embarrassing.',
#   'start': 107386,
#   'end': 109606,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.9673421382904053,
#   'speaker': None},
#  {'text': 'And people would come over and help me with the goddamn weights.',
#   'start': 109678,
#   'end': 111982,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.4913993775844574,
#   'speaker': None},
#  {'text': "Here's how you're supposed to use this.",
#   'start': 112006,
#   'end': 113802,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.8024411797523499,
#   'speaker': None},
#  {'text': 'It was humiliating and maybe I was pressing £65 or something at that point, but what am I going to do?',
#   'start': 113936,
#   'end': 120642,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.9167715311050415,
#   'speaker': None},
#  {'text': "I'm going to lift up £150 and injure myself right off the bat.",
#   'start': 120656,
#   'end': 124266,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.9240934252738953,
#   'speaker': None},
#  {'text': "No, I had to go in there and strip down and put my skinny goddamn self in front of the mirror and think, Son of a bitch, there's all these monsters in the gym who've been lifting weights for ten years and I'm struggling to get £50 off the bar.",
#   'start': 124388,
#   'end': 135990,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.9513323307037354,
#   'speaker': None},
#  {'text': "Tough luck for me, but I could lift £50 and it wasn't very long until I could lift 75 and, well, you know how it goes.",
#   'start': 136100,
#   'end': 143360,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.5556160807609558,
#   'speaker': None},
#  {'text': "And I never injured myself when I was weight lifting and the reason for that was I never pushed myself past where I knew I could go and I pushed myself a lot I gained £35 of muscle in about three years in University I kind of had to quit because I was eating so goddamn much I couldn't stand it.",
#   'start': 143750,
#   'end': 160170,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.8002011775970459,
#   'speaker': None},
#  {'text': 'I was eating like six meals a day.',
#   'start': 160220,
#   'end': 161814,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.8749282360076904,
#   'speaker': None},
#  {'text': "It was just taking up too much time but there's a humility in determining what it is that the wretched creature that you are can actually manage aim low and I don't mean don't aim And I don't mean don't aim up but you have to accept the fact that you can set yourself a goal that you can attain and there's not going to be much glory in it to begin with because if you're not in very good shape the goal that you could attain tomorrow isn't very glorious but it's a hell of a lot better than nothing and it beats the hell out of bitterness and it's way better than blaming someone else.",
#   'start': 161852,
#   'end': 194598,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.3765470087528229,
#   'speaker': None},
#  {'text': "It's way less dangerous and you could do it and what's cool about it there's a statement in the new testament it's called the Matthew principle and economists use it to describe how the economy and the world works to those who have everything more will be given from those who have nothing everything will be taken.",
#   'start': 194684,
#   'end': 211206,
#   'sentiment': 'POSITIVE',
#   'confidence': 0.7153332233428955,
#   'speaker': None},
#  {'text': "It's like what's very pessimistic in some sense because it means that as you start to fail you fail more and more rapidly but it also means that as you start to succeed you succeed more and more rapidly and so you take an incremental step and, well, now you can lift £55 instead of £52.5.",
#   'start': 211328,
#   'end': 228296,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.4416009783744812,
#   'speaker': None},
#  {'text': 'You think, well, what the hell is that?',
#   'start': 228306,
#   'end': 230490,
#   'sentiment': 'NEGATIVE',
#   'confidence': 0.8044020533561707,
#   'speaker': None},
#  {'text': "It's one step on a very long journey and it starts to compound on you so a small step today means puts you in a position to take a slight bigger step the next day and then that puts you in a position to take a slightly bigger step the next day and you do that for two or three years, man.",
#   'start': 230660,
#   'end': 246678,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.6300150752067566,
#   'speaker': None},
#  {'text': "You're starting to stride.",
#   'start': 246704,
#   'end': 247570,
#   'sentiment': 'NEUTRAL',
#   'confidence': 0.6852948665618896,
#   'speaker': None}]

# %%
entity_detection
# Out:
# [{'entity_type': 'injury',
#   'text': 'injure myself',
#   'start': 122624,
#   'end': 123282},
#  {'entity_type': 'money_amount',
#   'text': '£50',
#   'start': 134624,
#   'end': 134742},
#  {'entity_type': 'occupation',
#   'text': 'economists',
#   'start': 203984,
#   'end': 204454},
#  {'entity_type': 'money_amount',
#   'text': '£55',
#   'start': 225802,
#   'end': 226978},
#  {'entity_type': 'money_amount',
#   'text': '£52.5',
#   'start': 227456,
#   'end': 228296}]

# %%
import requests
import pprint
import json
import time
from api_keys import assemblyAI_key


# upload_endpoint = 'https://api.assemblyai.com/v2/upload'
# transcript_endpoint = 'https://api.assemblyai.com/v2/transcript'

# headers_auth_only = {'authorization': assemblyAI_key}

headers = {
    "authorization": assemblyAI_key,
    "content-type": "application/json"
}


# CHUNK_SIZE = 5_242_880  # 5MB


# def upload(filename):
#     def read_file(filename):
#         with open(filename, 'rb') as f:
#             while True:
#                 data = f.read(CHUNK_SIZE)
#                 if not data:
#                     break
#                 yield data

#     upload_response = requests.post(upload_endpoint,
#                                     headers=headers_auth_only,
#                                     data=read_file(filename))
#     pprint.pprint(upload_response.json())
#     return upload_response.json()['upload_url']


# # def transcribe(audio_url):
# #     transcript_request = {
# #         'audio_url': audio_url,
# #         'auto_chapters': True,
# #         'auto_highlights': True,
# #         "content_safety": True,
# #         "iab_categories": True,
# #         "sentiment_analysis": True,
# #         "entity_detection": True

# #     }

#     transcript_response = requests.post(transcript_endpoint,
#                                         json=transcript_request,
#                                         headers=headers)
#     pprint.pprint(transcript_response.json())
#     return transcript_response.json()['id']


def poll(transcript_id):
    polling_endpoint = 'https://api.assemblyai.com/v2/transcript' + '/' + "o4ohxoydd1-1d21-4d09-b9fb-bd4b084f9bce"
    polling_response = requests.get(polling_endpoint, headers=headers)
    print(polling_response)
    if polling_response.json()['status'] == 'completed':

        filename = transcript_id + '.json'
        with open(filename, 'w') as f:
            whole_file = polling_response.json()
            json.dump(whole_file, f, indent=4)

        # filename = transcript_id + '.txt'
        # with open(filename, 'w') as f:
        #     f.write(polling_response.json()['text'])

        # filename = transcript_id + '_chapters.json'
        # with open(filename, 'w') as f:
        #     chapters = polling_response.json()['chapters']
        #     json.dump(chapters, f, indent=4)

        # filename = transcript_id + '_highlights.json'
        # with open(filename, 'w') as f:
        #     data = polling_response.json()['auto_highlights_result']
        #     json.dump(data, f, indent=4)

        print('Transcript saved')
        return True

    filename = transcript_id + 'ERROR.json'
    with open(filename, 'w') as f:
        json.dump(polling_response.json(), f, indent=4)
    return False


def pipeline(filename):
    # audio_url = upload(filename)
    # transcribe_id = transcribe(audio_url)
    while True:
        result = poll("o4oj20ozc8-c7f3-4635-ba21-fb86ec935df4")
        if result:
            break
        print("waiting for 60 seconds")
        time.sleep(60)


# if __name__ == '__main__':
pipeline('podcast1.mp3')
# Out:
# <Response [200]>
# waiting for 60 seconds
# <Response [200]>
# waiting for 60 seconds

# %%
polling_endpoint = 'https://api.assemblyai.com/v2/transcript' + '/' + "o4ohxoydd1-1d21-4d09-b9fb-bd4b084f9bce"
polling_response = requests.get(polling_endpoint, headers=headers)
print(polling_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\conda_tmp/ipykernel_19144/3814952400.py in <module>
#       1 polling_endpoint = 'https://api.assemblyai.com/v2/transcript' + '/' + "o4ohxoydd1-1d21-4d09-b9fb-bd4b084f9bce"
# ----> 2 polling_response = requests.get(polling_endpoint, headers=headers)
#       3 print(polling_response)
#
# NameError: name 'requests' is not defined

# %%
headers = {
    "authorization": assemblyAI_key,
    "content-type": "application/json"
}

# %%
headers
# Out:
# {'authorization': '537b5d0df3754befab7f1bec13441ea2',
#  'content-type': 'application/json'}

# %%
from api_keys import assemblyAI_key

# %%
assemblyAI_key
# Out:
# '537b5d0df3754befab7f1bec13441ea2'
